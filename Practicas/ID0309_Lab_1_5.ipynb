# %% [markdown]
# #ID0309 - Aprendizaje Estadístico
#
# ### Otoño 2023
#
# ### ID0309_Lab_1-5
#
# **Enrique Naredo García**
#
# <font size = 2>
# ©️ Todos los derechos reservados. All rights reserved.
#
# *Nota: El presente documento es una herramienta diseñada única y exclusivamente para los estudiantes de la asignatura arriba mencionada. Se recuerda no compartir esta información fuera de los integrantes registrados en este curso. La reproducción total o parcial de este documento requiere autorización por escrito del titular del copyright.*
# </font>

# %% [markdown]
# #Reducción de dimensionalidad

# %% [markdown]
# La reducción de dimensionalidad es una técnica crucial en el análisis de datos para simplificar conjuntos complejos de datos y encontrar patrones ocultos.
# * Uno de los métodos más efectivos para **reducir la dimensionalidad de datos** mixtos es el Análisis Factorial de Datos Mixtos (FAMD).
# * El FAMD es un método de análisis factorial que se utiliza para conjuntos de datos con múltiples tipos de variables, incluyendo variables cuantitativas y cualitativas.
# * El FAMD utiliza una matriz de covarianza mixta para estimar las varianzas y covarianzas de los datos, y luego aplica un análisis de valores propios para reducir la dimensionalidad del conjunto de datos.
# * El resultado es un conjunto de factores que explican la mayor parte de la variabilidad en los datos originales.

# %%
# instalación de librería prince
# que nos proporciona la implementación de FAMD en Python
# !pip install prince
# Out:
# Collecting prince
#   Downloading prince-0.12.0-py3-none-any.whl (415 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 415.1/415.1 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: altair<6.0.0,>=4.2.2 in /usr/local/lib/python3.10/dist-packages (from prince) (4.2.2)
# Requirement already satisfied: pandas<3.0.0,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from prince) (1.5.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from prince) (1.2.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0.0,>=4.2.2->prince) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6.0.0,>=4.2.2->prince) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0.0,>=4.2.2->prince) (4.19.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from altair<6.0.0,>=4.2.2->prince) (1.23.5)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0.0,>=4.2.2->prince) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.4.1->prince) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=1.4.1->prince) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.2->prince) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.2->prince) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.0.2->prince) (3.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=4.2.2->prince) (0.9.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<3.0.0,>=1.4.1->prince) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6.0.0,>=4.2.2->prince) (2.1.3)
# Installing collected packages: prince
# Successfully installed prince-0.12.0

# %%
# importa librerías
import pandas as pd
from prince import FAMD

# %%
# Carga el dataset: Iris
# desde el repositorio de la UCI
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
                 header=None, names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])

# %%
# función que muestra los primeros n registros.
n = 8
df.head(n)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa

# %% [markdown]
# Noten que en este caso se reducen de 4 a 2 dimensiones.

# %%
# parametros de FAMD
famd = FAMD(
    # número de dimensiones por usar
    n_components=2,
    # número de iteraciones
    n_iter=3,
    copy=True,
    check_input=True,
    random_state=77,
    engine="sklearn",
    handle_unknown="error"
)

# %% [markdown]
# Se aplica FAMD al dataframe

# %%
# ajuste del modelo a los datos
famd = famd.fit(df)

# %% [markdown]
# Y a continuación podemos apreciar el porcentaje de variación atrapado por cada "valor propio" (eigenvalue).

# %%
# resumen de eigenvalues
famd.eigenvalues_summary
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              3.383        67.66%                     67.66%
# 1              1.054        21.07%                     88.73%

# %%
# coordenadas de cada fila
famd.row_coordinates(df).head()
# Out:
# component         0         1
# 0         -2.462285 -0.562588
# 1         -2.285625  0.477469
# 2         -2.548704  0.176470
# 3         -2.486654  0.404778
# 4         -2.578481 -0.714069

# %%
# coordenadas de cada columna
famd.column_coordinates_
# Out:
# component            0         1
# variable
# sepal_length  0.768708  0.117018
# sepal_width   0.215726  0.724380
# petal_length  0.985110  0.001258
# petal_width   0.937054  0.009413
# class         0.952478  0.403351

# %% [markdown]
# Muestra gráfico de dispersión.

# %%
# gráfico de dispersión
# se pueden cambiar los índices de los componentes
famd.plot(df, x_component=0, y_component=1)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Contribución de cada fila y columna a cada componente.

# %%
# contribución de cada fila a cada componente
famd.row_contributions_.sort_values(0, ascending=False)
# Out:
# component             0         1
# 118        2.200059e-02  0.000709
# 122        1.721284e-02  0.002902
# 22         1.694475e-02  0.001877
# 135        1.614199e-02  0.007468
# 105        1.566373e-02  0.006726
# ..                  ...       ...
# 81         2.316640e-05  0.021753
# 59         1.892286e-05  0.011465
# 64         5.106128e-06  0.004247
# 79         4.115137e-06  0.012289
# 60         1.263971e-07  0.050581
#
# [150 rows x 2 columns]

# %%
# contribución de cada columna a cada componente
famd.column_contributions_.style.format('{:.0%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b3a0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >component</th>
#       <th id="T_2b3a0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2b3a0_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b3a0_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_2b3a0_row0_col0" class="data row0 col0" >23%</td>
#       <td id="T_2b3a0_row0_col1" class="data row0 col1" >11%</td>
#     </tr>
#     <tr>
#       <th id="T_2b3a0_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_2b3a0_row1_col0" class="data row1 col0" >6%</td>
#       <td id="T_2b3a0_row1_col1" class="data row1 col1" >69%</td>
#     </tr>
#     <tr>
#       <th id="T_2b3a0_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_2b3a0_row2_col0" class="data row2 col0" >29%</td>
#       <td id="T_2b3a0_row2_col1" class="data row2 col1" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_2b3a0_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_2b3a0_row3_col0" class="data row3 col0" >28%</td>
#       <td id="T_2b3a0_row3_col1" class="data row3 col1" >1%</td>
#     </tr>
#     <tr>
#       <th id="T_2b3a0_level0_row4" class="row_heading level0 row4" >class</th>
#       <td id="T_2b3a0_row4_col0" class="data row4 col0" >28%</td>
#       <td id="T_2b3a0_row4_col1" class="data row4 col1" >38%</td>
#     </tr>
#   </tbody>
# </table>
